# %%
import pandas as pd
import numpy as np
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
df = pd.read_csv(url, header = None)
df.head(10)
df.tail(10)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style",
           "drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type",
          "num-of-cylinders","engine-type","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm",
          "city-mpg","highway-mpg","price"]
df.columns = headers
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-type  \
# ...

# %%
path = "D:/archive.csv"
df.to_csv(path)

# %%
df.dtypes
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-type  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.describe(include="all")
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           205        205          205             205  205.000000  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-type          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null object
# stroke               205 non-null object
# ...

# %%
#df["symboling"] = df["symboling"] + 1
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-type  \
# ...

# %%
#to drop the values with Na/NaN , axis- 0, removes row, 1 removes column
#inplace=True saves the changes to df
df.dropna(subset=["price"], axis=0, inplace= True )
df.head(10)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
# 5          2              122.0         audi       gas        std
# 6          1              158.0         audi       gas        std
# 7          1              122.0         audi       gas        std
# 8          1              158.0         audi       gas      turbo
# 9          0              122.0         audi       gas      turbo
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# ...

# %%
#replace ? with NaN
df['normalized-losses'] = df['normalized-losses'].replace('?',np.nan).astype(float)
df["normalized-losses"] = df["normalized-losses"].fillna(value=df["normalized-losses"].mean())
df["normalized-losses"]

df["num-of-doors"] = df["num-of-doors"].replace('?',np.nan)
df["num-of-doors"] = df["num-of-doors"].fillna(value="four")
df["num-of-doors"]

df["bore"] = df["bore"].replace('?',np.nan).astype(float)
df["bore"] = df["bore"].fillna(value=df["bore"].mean())
df["bore"].iloc[50:61]

df["stroke"] = df["stroke"].replace('?',np.nan).astype(float)
df["stroke"] = df["stroke"].fillna(value=df["stroke"].mean())
df["stroke"].iloc[50:61]

df["horsepower"] = df["horsepower"].replace('?',np.nan).astype(float)
df["horsepower"] = df["horsepower"].fillna(value=df["horsepower"].mean())
df["horsepower"].iloc[125:135]

df["peak-rpm"] = df["peak-rpm"].replace('?',np.nan).astype(float)
df["peak-rpm"] = df["peak-rpm"].fillna(value=df["peak-rpm"].mean())
df["peak-rpm"].iloc[125:135]

df["price"] = df["price"].replace('?',np.nan).astype(float)
df["price"] = df["price"].fillna(value=df["price"].mean())

df["price"].iloc[0:15]
# Out:
# 0     13495.000000
# 1     16500.000000
# 2     16500.000000
# 3     13950.000000
# 4     17450.000000
# 5     15250.000000
# 6     17710.000000
# 7     18920.000000
# 8     23875.000000
# 9     13207.129353
# 10    16430.000000
# 11    16925.000000
# 12    20970.000000
# 13    21105.000000
# 14    24565.000000
# Name: price, dtype: float64

# %%
#Data normalization 
#Simple feature scaling
df["symboling"] = df["symboling"]/df["symboling"].max()
df["symboling"]

#min-max method
df["symboling"] = df["symboling"]-df["symboling"].min()/df["symboling"].max()-df["symboling"].min()
df["symboling"]

#zscore
df["symboling"] = df["symboling"]-df["symboling"].mean()/df["symboling"].std()
df["symboling"]
# Out:
# 0     -1.649290
# 1     -1.649290
# 2     -0.465034
# 3     -1.057162
# 4     -1.057162
#          ...
# 200    0.719222
# 201    0.719222
# 202    0.719222
# 203    0.719222
# 204    0.719222
# Name: symboling, Length: 205, dtype: float64

# %%
bins = np.linspace(min(df["price"]),max(df["price"]),4)
group_names = ["Low","Medium","High"]
df["price-binned"] = pd.cut(df["price"],bins,labels=group_names,include_lowest=True)
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-e52a76546875> in <module>
# ----> 1 bins = np.linspace(min(df["price"]),max(df["price"]),4)
#       2 group_names = ["Low","Medium","High"]
#       3 df["price-binned"] = pd.cut(df["price"],bins,labels=group_names,include_lowest=True)
#       4 df.head(20)
#
# ~\Anaconda3\lib\site-packages\numpy\core\function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     133     # Convert float/complex array scalars to float, gh-3504
#     134     # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 135     start = asanyarray(start) * 1.0
#     136     stop  = asanyarray(stop)  * 1.0
#     137
#
# TypeError: ufunc 'multiply' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable
